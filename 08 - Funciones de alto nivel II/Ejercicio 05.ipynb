# %% [markdown]
# # Ejercicio 5. Formatenado boletines de notas para impresión
#
# ## Enunciado
#
# 1. Crear un formateador de notas. recibirá un parámetro,
# - una lista de tuplas en las que el elemento 0 será el nombre del alumno y el resto de items serán pares (Asignatura, nota).
#
# y devolverá una cadena, una única cadena que al imprimirla muestre el boletín de notas
#
# 2. Crear un creador de formateadores, cuyo parámetro de entrada será una función formateadora similar a la del punto uno. Y cuya salida será una función que recibirá una lista y cuya salida será una cadena con todos los boletines correspondientes a la lista.
#
# Sirva como ejemplo
#
# ```
# >>> notas = [('Alumno 1', ('Ciencias', 7)), ('Alumna 2', ('Ciencias, 8.5))]
#
# >>> mi_formateador = crea_formateador(formateador)
# >>> mi_formateador(notas)
# 'Alumno 1\nCiencias: 7\n--\n\nAlumna 2\nCiencias: 8.5\n--\n\n'
# >>> print(mi_formateador(notas))
# Alumno 1
# Ciencias: 7
# --
#
# Alumna 2
# Ciencias: 8.5
# --
# ```

# %% [markdown]
# ## Ayuda a la implementación
#
# Al ser opcional, si no se necesita no se pone este apartado
