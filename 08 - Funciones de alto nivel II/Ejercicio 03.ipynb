# %% [markdown]
# # Ejercicio 3. Crea cifradores cesar a tu gusto
#
# ## Enunciado
#
# Partiendo de lo que sabes de cifradores cesar, crea un constructor de cifradores con funciones que devuelven funciones

# %% [markdown]
# ## Ayuda a la implementación
#
# Al ser opcional, si no se necesita no se pone este apartado
