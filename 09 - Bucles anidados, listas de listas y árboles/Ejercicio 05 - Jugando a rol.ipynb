# %% [markdown]
# # Ejercicio 5. Jugando a rol.
#
# ## Enunciado
#
# Recientemente te has unido a un club de rol y te has ofrecido para llevar un seguimiento de las partidas en curso aprovechando que estás aprendiendo a programar en Python.
#
# En este momento hay tres partidas en curso:
#
# - Partida 1:
#   - Universo: Reinos olvidados
#   - Jugadores:
#     - María, guerrera, 3126 puntos
#     - Juan, brujo, 2843 puntos
#     - Pedro, bardo, 2345 puntos,
#     - Ana, exploradora, 2157puntos
# - Partida 2:
#   - Universo: Dragonlance
#   - Jugadores:
#     - Tony, druida, 23126 puntos
#     - Emilio, paladín, 12843 puntos
#     - Rosa, hechicera, 21345 puntos
#     - Lola, pícara, 20157 puntos
# - Partida 3:
#   - Universo: Eberron
#   - Jugadores:
#     - Amelia, druida, 223126 puntos
#     - Alberto, paladín, 212843 puntos
#     - Adela, maga, 321345 puntos
#     - Ágata, guerrera, 220157 puntos

# %% [markdown]
# Crea una estructura de datos que mantenga en la variable `partidas` el estado actual de las partidas en curso. Para cada partida se debe almacenar el nombre del universo donde está ambientada y la lista de características de cada participante.

# %% [markdown]
# Has encontrado en Stack Overflow que alguien ya tenía una lista con los límites para cada nivel de personaje de forma que un personaje es de nivel 1 si tiene entre 0 y 299 puntos de experiencia, nivel 2 entre 300 y 899 y así sucesivamente.

# %%
niveles = [
    0, 300, 900, 2700,
    6500, 14000, 23000,
    34000, 48000, 64000,
    85000, 100000, 120000,
    140000, 165000, 195000,
    225000, 265000, 305000, 355000]

# %% [markdown]
# Después de haber creado la estructura de datos y, usando la lista de niveles, escribe el código necesario para agregar a cada jugador el nivel en el que se encuentra su personaje.

# %% [markdown]
# ## Ayuda a la implementación
#
# Utiliza bucles anidados para recorrer las diferentes listas de la estructura de datos.
#
# Puedes utilizas la función `enumerate` para acceder a un elemento de una lista y su índice al recorrer la lista con un bucle `for`.
#
# Recuerda que el primer elemento de una lista tiene el índice 0.
#
# Para imprimir el resultado de forma más cómoda de leer puedes importar la librería `pprint` y usarla para imprimir el contenido de la variable `partidas` de la siguiente manera:
#
# ```python
# from pprint import pprint
#
# pprint(partidas)
# ```
#
# Esto imprimirá el resultado como:
#
# ```
# [['Reinos olvidados',
#   ['María', 'Guerrera', 3126, 4],
#   ['Juan', 'Brujo', 2843, 4],
#   ['Pedro', 'Bardo', 2345, 3],
#   ['Ana', 'Exploradora', 2157, 3]],
#  ['Dragonlance',
#   ['Tony', 'Druida', 23126, 7],
#   ['Emilio', 'Paladín', 12843, 5],
#   ['Rosa', 'Hechicera', 21345, 6],
#   ['Lola', 'Pícara', 20157, 6]],
#  ['Eberron',
#   ['Amelia', 'Druida', 223126, 16],
#   ['Alberto', 'Paladín', 212843, 16],
#   ['Adela', 'Maga', 321345, 19],
#   ['Ágata', 'Guerrera', 220157, 16]]]
# ```
#
# Utiliza este resultado para comprobar que los datos calculados en tu código son correctos.
